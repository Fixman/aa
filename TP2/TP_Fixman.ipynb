# %%
# %pylab inline

import pandas
import matplotlib
import seaborn
import itertools

from matplotlib import pyplot
from collections import Counter
from collections import defaultdict
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from players import RandomPlayer, QLearningPlayer
from connectfour import ConnectFour, WinnerState

# %%
pyplot.rcParams['figure.figsize'] = 12, 6

# %% [markdown]
# # Definitions

# %%
def playAndPlot(red, blue, games = 1000):
    plotGames(playGames(red, blue, games), [type(red).__name__, type(blue).__name__])

def playGames(red, blue, games = 1000):
    return numpy.array([ConnectFour(red, blue).play() for _ in range(games)])

def plotRollingAvg(games, players, size = 100):
    x = numpy.arange(games.size)
    states = [WinnerState.red, WinnerState.blue]
    for state, player in zip(states, players):
        y = numpy.cumsum(games == state) / (x + 1)
        pyplot.plot(x, y, label = player, color = state.name)

    pyplot.legend()
    pyplot.xlabel('Juegos')
    pyplot.ylabel('Proporción juegos ganados')
    
def plotGamesChunks(games, players):
    chunk_size = 1000    
    states = [WinnerState.red, WinnerState.blue]
    for state, player in zip(states, players):
#        for c in range(0, games.size/chunk_size):
 #       y = numpy.cumsum(games == state) / (x + 1)
        pyplot.plot(x, y, label = player, color = state.name)

    pyplot.legend()
    pyplot.xlabel('Juegos')
    pyplot.ylabel('Proporción juegos ganados')

def plotGames(games, players):
    x = numpy.arange(games.size)
    states = [WinnerState.red, WinnerState.blue]
    for state, player in zip(states, players):
        y = numpy.cumsum(games == state) / (x + 1)
        pyplot.plot(x, y, label = player, color = state.name)

    pyplot.legend()
    pyplot.xlabel('Juegos')
    pyplot.ylabel('Proporción juegos ganados')
    savefig('qlearn_vs_random_big.png')

# %% [markdown]
# # Random vs Random

# %%
playAndPlot(RandomPlayer(ConnectFour.moves), RandomPlayer(ConnectFour.moves), games = 1000)

# %% [markdown]
# # Q Learner vs Random

# %%
playAndPlot(QLearningPlayer(ConnectFour.moves), RandomPlayer(ConnectFour.moves), games = 1000000)

# %% [markdown]
# # Random vs Q Learner

# %%
playAndPlot(RandomPlayer(ConnectFour.moves), QLearningPlayer(ConnectFour.moves), games = 1000)

# %% [markdown]
# # Q Learner vs Q Learner

# %%
playAndPlot(QLearningPlayer(ConnectFour.moves), QLearningPlayer(ConnectFour.moves), games = 100000)

# %% [markdown]
# # How long until 75%

# %%
window = 100
a = QLearningPlayer(ConnectFour.moves)
b = RandomPlayer(ConnectFour.moves)
ratios = ((x, sum(playGames(a, b, window) == WinnerState.red) / window) for x in itertools.count(1))

# %%
wins = [next(ratios) for _ in range(100)]

# %%
pyplot.plot([x for x, _ in wins], [x for _, x in wins])

# %%
def rolling_avg(a, n = 100):
    ret = numpy.cumsum(a)
    ret[n:] = ret[n:] - ret[:-n]
    return ret[n - 1:] / n

# %%
b = QLearningPlayer(ConnectFour.moves)
games = (playGames(b, RandomPlayer(ConnectFour.moves), 1) for _ in itertools.count(0))
played = list(itertools.islice(games, 10000))

# %%
# k = rolling_avg(played)
# pyplot.plot(numpy.arange(k.size), k)

# %% [markdown]
# # Whitespace

# %% [markdown]
# &nbsp;
#
# &nbsp;
#
# &nbsp;
#
# &nbsp;
#
# &nbsp;
#
# &nbsp;
#
# &nbsp;
#
# &nbsp;
#
# &nbsp;
#
# &nbsp;
#
# &nbsp;
#
# &nbsp;
#
# &nbsp;
#
# &nbsp;
#
# &nbsp;
#
# &nbsp;
#
# &nbsp;
#
# &nbsp;
#
# &nbsp;
#
# &nbsp;
#
# &nbsp;
#
# &nbsp;
#
# &nbsp;
#
# &nbsp;
#
# &nbsp;
#
# &nbsp;
#
# &nbsp;
#
# &nbsp;
#
# &nbsp;
#
# &nbsp;
#
# &nbsp;
#
# &nbsp;
#
# &nbsp;
#
# &nbsp;
#
# &nbsp;
#
# &nbsp;
#
# &nbsp;
#
# &nbsp;
#
# &nbsp;
#
# &nbsp;
#
# &nbsp;
#
# &nbsp;
#
# &nbsp;
#
# &nbsp;
#
# &nbsp;
#
# &nbsp;
#
# &nbsp;
#
# &nbsp;
#
# &nbsp;
#
# &nbsp;
#
# &nbsp;
#
# &nbsp;
#
# &nbsp;
#
# &nbsp;
#
# &nbsp;
#
# &nbsp;
#
# &nbsp;
#
# &nbsp;
#
# &nbsp;
#
# &nbsp;
#
# &nbsp;
#
# &nbsp;
#
# &nbsp;
#
# &nbsp;
#
# &nbsp;
#
# &nbsp;
#
# &nbsp;
#
# &nbsp;
#
# &nbsp;
#
# &nbsp;
